# %%
import tensorflow as tf

# %%
import zipfile
zip_ref = zipfile.ZipFile("drive/MyDrive/Colab Notebooks/data.zip","r")
zip_ref.extractall()
zip_ref.close()

# %%
# !ls "data"
# Out:
# test  train

# %%
# !ls "data/train"
# Out:
# 00000  00004  00008  00012  00016  00020  00024  00028	00032  00036  00040
# 00001  00005  00009  00013  00017  00021  00025  00029	00033  00037  00041
# 00002  00006  00010  00014  00018  00022  00026  00030	00034  00038  00042
# 00003  00007  00011  00015  00019  00023  00027  00031	00035  00039

# %%
# !ls "data/train/00000"
# Out:
# 00000_00000.ppm  00001_00023.ppm  00003_00016.ppm  00005_00009.ppm
# 00000_00001.ppm  00001_00024.ppm  00003_00017.ppm  00005_00010.ppm
# 00000_00002.ppm  00001_00025.ppm  00003_00018.ppm  00005_00011.ppm
# 00000_00003.ppm  00001_00026.ppm  00003_00019.ppm  00005_00012.ppm
# 00000_00004.ppm  00001_00027.ppm  00003_00020.ppm  00005_00013.ppm
# 00000_00005.ppm  00001_00028.ppm  00003_00021.ppm  00005_00014.ppm
# 00000_00006.ppm  00001_00029.ppm  00003_00022.ppm  00005_00015.ppm
# 00000_00007.ppm  00002_00000.ppm  00003_00023.ppm  00005_00016.ppm
# 00000_00008.ppm  00002_00001.ppm  00003_00024.ppm  00005_00017.ppm
# 00000_00009.ppm  00002_00002.ppm  00003_00025.ppm  00005_00018.ppm
# 00000_00010.ppm  00002_00003.ppm  00003_00026.ppm  00005_00019.ppm
# 00000_00011.ppm  00002_00004.ppm  00003_00027.ppm  00005_00020.ppm
# 00000_00012.ppm  00002_00005.ppm  00003_00028.ppm  00005_00021.ppm
# 00000_00013.ppm  00002_00006.ppm  00003_00029.ppm  00005_00022.ppm
# ...

# %%
# View an image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import os

def view_random_image(target_dir, target_class):
  # Setup target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  # Read in the image and plot it using matplotlib
  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(int(target_class))
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00000")
# Out:
# Image shape: (28, 27, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00001")
# Out:
# Image shape: (46, 48, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00002")
# Out:
# Image shape: (62, 63, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00003")
# Out:
# Image shape: (55, 51, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00004")
# Out:
# Image shape: (47, 46, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00005")
# Out:
# Image shape: (57, 57, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00006")
# Out:
# Image shape: (72, 68, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00007")
# Out:
# Image shape: (42, 42, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00008")
# Out:
# Image shape: (49, 49, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00009")
# Out:
# Image shape: (88, 87, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00010")
# Out:
# Image shape: (35, 38, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00011")
# Out:
# Image shape: (81, 92, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00012")
# Out:
# Image shape: (62, 63, 3)

# %%
img = view_random_image(target_dir="data/train/",
                        target_class="00013")
# Out:
# Image shape: (45, 48, 3)

# %%
targets = ["Speed limit 20 kilometrs per hour"]
targets.append("speed limit 30 kilometrs per hour")
targets.append("speed limit 50 kilometrs per hour")
targets.append("speed limit 60 kilometrs per hour")
targets.append("speed limit 70 kilometrs per hour")
targets.append("speed limit 80 kilometrs per hour")
targets.append("speed of 80 not allowed")
targets.append("speed limit 100 kilometrs per hour")
targets.append("speed limit 120 kilometrs per hour")
targets.append("No overtaking")
targets.append("")
targets.append("right of way")
targets.append("closed quadrilateral")

# %%
targets
# Out:
# ['Speed limit 20 kilometrs per hour',
#  'speed limit 30 kilometrs per hour',
#  'speed limit 50 kilometrs per hour',
#  'speed limit 60 kilometrs per hour',
#  'speed limit 70 kilometrs per hour',
#  'speed limit 80 kilometrs per hour',
#  'speed of 80 not allowed',
#  'speed limit 100 kilometrs per hour',
#  'speed limit 120 kilometrs per hour',
#  'No overtaking',
#  '']
